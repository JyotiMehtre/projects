# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.5-flash", model_provider="google_vertexai")
model.invoke("Hello, world!")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\aiplatform\initializer.py:367, in _Config.project(self)
#     366 try:
# --> 367     self._set_project_as_env_var_or_google_auth_default()
#     368     project_id = self._project
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\aiplatform\initializer.py:114, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     113 else:
# --> 114     credentials, project = google.auth.default()
#     115     self._credentials = self._credentials or credentials
#
# File ~\AppData\Roaming\Python\Python311\site-packages\google\auth\_default.py:685, in default(scopes, request, quota_project_id, default_scopes)
#     683         return credentials, effective_project_id
# --> 685 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 from langchain.chat_models import init_chat_model
# ----> 3 model = init_chat_model("gemini-2.5-flash", model_provider="google_vertexai")
#       4 model.invoke("Hello, world!")
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chat_models\base.py:314, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     306     warnings.warn(
#     307         f"{config_prefix=} has been set but no fields are configurable. Set "
#     308         f"`configurable_fields=(...)` to specify the model params that are "
#     309         f"configurable.",
#     310         stacklevel=2,
#     311     )
#     313 if not configurable_fields:
# --> 314     return _init_chat_model_helper(
#     315         cast("str", model),
#     316         model_provider=model_provider,
#     317         **kwargs,
#     318     )
#     319 if model:
#     320     kwargs["model"] = model
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chat_models\base.py:366, in _init_chat_model_helper(model, model_provider, **kwargs)
#     363     _check_pkg("langchain_google_vertexai")
#     364     from langchain_google_vertexai import ChatVertexAI
# --> 366     return ChatVertexAI(model=model, **kwargs)
#     367 if model_provider == "google_genai":
#     368     _check_pkg("langchain_google_genai")
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_vertexai\chat_models.py:1493, in ChatVertexAI.__init__(self, model_name, **kwargs)
#    1487         suggestion = (
#    1488             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1489         )
#    1490         logger.warning(
#    1491             f"Unexpected argument '{arg}' provided to ChatVertexAI.{suggestion}"
#    1492         )
# -> 1493 super().__init__(**kwargs)
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_google_vertexai\_base.py:147, in _VertexAIBase.validate_project(self)
#     145         self.project = self.credentials.project_id
#     146     else:
# --> 147         self.project = initializer.global_config.project
#     148 return self
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\aiplatform\initializer.py:370, in _Config.project(self)
#     368     project_id = self._project
#     369 except GoogleAuthError as exc:
# --> 370     raise GoogleAuthError(project_not_found_exception_str) from exc
#     372 if not project_id and not self.api_key:
#     373     raise ValueError(project_not_found_exception_str)
#
# GoogleAuthError: Unable to find your project. Please provide a project ID by:
# - Passing a constructor argument
# - Using vertexai.init()
# - Setting project using 'gcloud config set project my-project'
# - Setting a GCP environment variable
# - To create a Google Cloud project, please follow guidance at https://developers.google.com/workspace/guides/create-project
