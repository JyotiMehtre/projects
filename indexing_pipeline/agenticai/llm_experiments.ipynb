# %%
print("hello")
# Out:
# hello

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.5-flash-lite", model_provider="google_vertexai")

# %%
model.invoke("what is the capital of india")
# Out:
# Retrying langchain_google_vertexai.chat_models._completion_with_retry.<locals>._completion_with_retry_inner in 4.0 seconds as it raised PermissionDenied: 403 This API method requires billing to be enabled. Please enable billing on project #neural-cathode-466805-i3 by visiting https://console.developers.google.com/billing/enable?project=neural-cathode-466805-i3 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry. [reason: "BILLING_DISABLED"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "aiplatform.googleapis.com"
# }
# metadata {
#   key: "containerInfo"
#   value: "neural-cathode-466805-i3"
# }
# metadata {
#   key: "consumer"
#   value: "projects/neural-cathode-466805-i3"
# }
# , locale: "en-US"
# ...
